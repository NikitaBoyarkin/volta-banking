# %% [markdown]
# # A/B Test — KYC progress bar lift
#
# Volta Neobank portfolio — volta_ab_testing.

# %%
from volta_ab_testing import main

main()
# Out:
# ...
# VOLTA NEOBANK — KYC PROGRESS BAR A/B TEST
# ...
#
# Experiment data: (10000, 9)
#            count   sum  mean
# group
# control     5000  2791 0.558
# treatment   5000  3035 0.607
#
# ...
# SAMPLE SIZE CALCULATION
# ...
# Baseline KYC completion rate:  56.6%
# Minimum detectable effect:     +5%
# Required sample per arm:       1,517
# Total users needed:            3,034
# Experiment duration (300 starts/day): 10 days
#
# ...
# SRM CHECK (Sample Ratio Mismatch)
# ...
# Control group:     5,000
# Treatment group:   5,000
# Expected split:    50/50
# Chi-square:        0.0000
# P-value:           1.0000
# ✅ No SRM — Randomization looks clean
#
# ...
# COVARIATE BALANCE CHECK
# ...
#
# DEVICE:
# device     android    ios    web
# group
# control     45.200 40.200 14.600
# treatment   45.000 40.400 14.500
#
# AGE_GROUP:
# age_group  18-24  25-34  35-44    45+
# group
# control   20.500 35.400 29.200 14.900
# treatment 20.600 33.800 30.600 15.000
#
# CHANNEL:
# channel    app_store  google_play  referral  website
# group
# ...
