# %% [markdown]
# # User Segmentation — who are the users?
#
# Volta Neobank portfolio — volta_segmentation.

# %%
from volta_segmentation import main

main()
# Out:
# ...
# VOLTA NEOBANK — USER SEGMENTATION
# ...
#
# Dataset shape: (50000, 8)
# Users: 50,000
#
# Feature summary statistics:
#        monthly_tx_count  avg_tx_value_eur  savings_balance_eur  \
# count         50000.000         50000.000            50000.000
# mean             14.000            19.600             1421.770
# std              11.410            13.270             1792.650
# min               0.000             0.000                0.000
# 25%               5.200             9.550               15.120
# 50%              11.650            16.790              550.220
# 75%              19.730            27.600             2348.870
# max              51.220            64.630             7278.180
#
#        logins_per_week  p2p_transfers_month  tenure_days  monthly_revenue
# count        50000.000            50000.000    50000.000        50000.000
# mean             4.840                4.980      266.010            9.470
# ...
